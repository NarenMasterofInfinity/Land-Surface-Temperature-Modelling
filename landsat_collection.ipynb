# %%
import pandas as pd

df = pd.read_csv("../data/landsat_collection_dates.csv", encoding="latin-1")

# %%
df["Date Acquired"] = pd.to_datetime(df["Date Acquired"], errors="coerce")
df_2015plus = df[df["Date Acquired"] > "2015-01-01"]

# %%
df_2015plus["Date Acquired"].to_csv("good_landsat_dates.csv", index = False)
